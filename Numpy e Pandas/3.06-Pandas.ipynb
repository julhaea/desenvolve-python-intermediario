# %% [markdown]
# > Projeto Desenvolve <br>
# Programação Intermediária com Python <br>
# Profa. Camila Laranjeira (mila@projetodesenvolve.com.br) <br>
#
# # 3.6 - Pandas

# %% [markdown]
# ## Exercícios
# Antes de continuar, baixe os arquivos das bases de dados de partidas em Copas do Mundo e salve na mesma pasta deste notebook.
# * https://raw.githubusercontent.com/camilalaranjeira/python-intermediario/main/fifa-wc/matches_1930_2022.csv
# * https://raw.githubusercontent.com/camilalaranjeira/python-intermediario/main/fifa-wc/matches_1991_2023.csv
#
# A célula a seguir já carrega os dados em CSV e ajusta as colunas para trabalharmos com os nomes traduzidos (como fizemos em aula).

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',12)

wcwomen_df = pd.read_csv('matches_1991_2023.csv')
wcmen_df   = pd.read_csv('matches_1930_2022.csv')
wc = pd.concat((wcwomen_df,wcmen_df)).reset_index()

nomes_traduzidos = {'home_team': 'time_1', 'away_team': 'time_2', 'home_score': 'gols_1', 'away_score': 'gols_2',
                    'Date': 'data', 'Year': 'ano', 'Host': 'país_sede', 'Attendance': 'comparecimento',
                    'Score': 'resultado', 'Round': 'rodada', 'home_goal': 'gols_1_detalhes', 'away_goal': 'gols_2_detalhes',
                    'home_own_goal': 'gols_1_contra', 'away_own_goal': 'gols_2_contra',
                    'home_penalty_goal': 'gols_1_penalti', 'away_penalty_goal': 'gols_2_penalti',
                    'home_red_card': 'cartao_vermelho_1', 'away_red_card': 'cartao_vermelho_2',
                    'home_yellow_card_long': 'cartao_amarelo_1', 'away_yellow_card_long': 'cartao_amarelo_2'}

wc = wc.loc[:, nomes_traduzidos.keys()]
wc.columns = nomes_traduzidos.values()

copa = wc['ano'].apply( lambda x: 'Masculina' if x % 2 == 0 else 'Feminina').astype('string')
wc['copa'] = copa
display(wc)
# Out:
#              time_1     time_2  gols_1  gols_2        data   ano  \
# 0             Spain    England       1       0  2023-08-20  2023
# 1            Sweden  Australia       2       0  2023-08-19  2023
# 2         Australia    England       1       3  2023-08-16  2023
# 3             Spain     Sweden       2       1  2023-08-15  2023
# 4         Australia     France       0       0  2023-08-12  2023
# ...             ...        ...     ...     ...         ...   ...
# 1307      Argentina     France       1       0  1930-07-15  1930
# 1308     Yugoslavia     Brazil       2       1  1930-07-14  1930
# 1309        Romania       Peru       3       1  1930-07-14  1930
# 1310  United States    Belgium       3       0  1930-07-13  1930
# 1311         France     Mexico       4       1  1930-07-13  1930
#
#                    país_sede  comparecimento    resultado             rodada  \
# 0     Australia, New Zealand           75784          1–0              Final
# 1     Australia, New Zealand           49461          2–0  Third-place match
# 2     Australia, New Zealand           75784          1–3        Semi-finals
# 3     Australia, New Zealand           43217          2–1        Semi-finals
# 4     Australia, New Zealand           49461  (7) 0–0 (6)     Quarter-finals
# ...                      ...             ...          ...                ...
# 1307                 Uruguay           23409          1–0        Group stage
# 1308                 Uruguay           24059          2–1        Group stage
# 1309                 Uruguay            2549          3–1        Group stage
# 1310                 Uruguay           18346          3–0        Group stage
# 1311                 Uruguay            4444          4–1        Group stage
#
#                                         gols_1_detalhes  \
# 0                                    Olga Carmona · 29’
# 1                                Kosovare Asllani · 62’
# 2                                        Sam Kerr · 63’
# 3             Salma Paralluelo · 81’|Olga Carmona · 89’
# 4                                                   NaN
# ...                                                 ...
# 1307                                    Luis Monti · 81
# 1308             Aleksandar Tirnanić · 21|Ivan Bek · 30
# 1309  Adalbert Deșu · 1|Constantin Stanciu · 79|Nico...
# 1310  Bart McGhee · 23|Tom Florie · 45|Bert Patenaud...
# 1311  Lucien Laurent · 19|Marcel Langiller · 40|Andr...
#
#                                         gols_2_detalhes gols_1_contra  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2     Ella Toone · 36’|Lauren Hemp · 71’|Alessia Rus...           NaN
# 3                               Rebecka Blomqvist · 88’           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 1307                                                NaN           NaN
# 1308                                     Preguinho · 62           NaN
# 1309                        Luis de Souza Ferreira · 75           NaN
# 1310                                                NaN           NaN
# 1311                                  Juan Carreño · 70           NaN
#
#      gols_2_contra             gols_1_penalti gols_2_penalti  \
# 0              NaN                        NaN            NaN
# 1              NaN  Fridolina Rolfö (P) · 30’            NaN
# 2              NaN                        NaN            NaN
# 3              NaN                        NaN            NaN
# 4              NaN                        NaN            NaN
# ...            ...                        ...            ...
# 1307           NaN                        NaN            NaN
# 1308           NaN                        NaN            NaN
# 1309           NaN                        NaN            NaN
# 1310           NaN                        NaN            NaN
# 1311           NaN                        NaN            NaN
#
#      cartao_vermelho_1     cartao_vermelho_2  \
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
# ...                ...                   ...
# 1307               NaN                   NaN
# 1308               NaN                   NaN
# 1309               NaN  Plácido Galindo · 70
# 1310               NaN                   NaN
# 1311               NaN                   NaN
#
#                                        cartao_amarelo_1  \
# 0                          ['78’|1:0|Salma Paralluelo']
# 1     ['88’|2:0|Elin Rubensson', '90+5’|2:0|Lina Hur...
# 2                                                   NaN
# 3                                                   NaN
# 4                             ['92’|0:0|Katrina Gorry']
# ...                                                 ...
# 1307                                                NaN
# 1308                                                NaN
# 1309                                                NaN
# 1310                                                NaN
# 1311                                                NaN
#
#                                        cartao_amarelo_2       copa
# 0                               ['55’|1:0|Lauren Hemp']   Feminina
# 1                           ['45+1’|1:0|Katrina Gorry']   Feminina
# 2     ['10’|0:0|Alex Greenwood', '90+5’|1:3|Chloe Ke...   Feminina
# 3                                                   NaN   Feminina
# 4                                                   NaN   Feminina
# ...                                                 ...        ...
# 1307                                                NaN  Masculina
# 1308                                                NaN  Masculina
# 1309                                                NaN  Masculina
# 1310                                                NaN  Masculina
# 1311                                                NaN  Masculina
#
# [1312 rows x 21 columns]

# %% [markdown]
# #### Q1.
# Faça as conversões de tipo necessárias para que a saída do comando `wc.info()` seja como apresentado a seguir. E **salve o novo dataframe** com o comando `df.to_csv('wc_formatado.csv')`.
#
# ```
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   time_1             1312 non-null   string
#  1   time_2             1312 non-null   string
#  2   gols_1             1312 non-null   int64
#  3   gols_2             1312 non-null   int64
#  4   data               1312 non-null   datetime64[ns]
#  5   ano                1312 non-null   int64
#  6   país_sede          1312 non-null   string
#  7   comparecimento     1312 non-null   int64
#  8   resultado          1312 non-null   string
#  9   rodada             1312 non-null   category
#  10  gols_1_detalhes    970 non-null    string
#  11  gols_2_detalhes    771 non-null    string
#  12  gols_1_contra      57 non-null     string
#  13  gols_2_contra      30 non-null     string
#  14  gols_1_penalti     170 non-null    string
#  15  gols_2_penalti     119 non-null    string
#  16  cartao_vermelho_1  59 non-null     string
#  17  cartao_vermelho_2  65 non-null     string
#  18  cartao_amarelo_1   834 non-null    string
#  19  cartao_amarelo_2   857 non-null    string
#  20  copa               1312 non-null   string
# ```

# %%
wc['time_1'] = wc['time_1'].astype('string')
wc['time_2'] = wc['time_2'].astype('string')
wc['gols_1'] = wc['gols_1'].astype('int64')
wc['gols_2'] = wc['gols_2'].astype('int64')
wc['data'] = pd.to_datetime(wc['data'])
wc['ano'] = wc['ano'].astype('int64')
wc['país_sede'] = wc['país_sede'].astype('string')
wc['comparecimento'] = wc['comparecimento'].astype('int64')
wc['resultado'] = wc['resultado'].astype('string')
wc['rodada'] = wc['rodada'].astype('category')
wc['gols_1_detalhes'] = wc['gols_1_detalhes'].astype('string')
wc['gols_2_detalhes'] = wc['gols_2_detalhes'].astype('string')
wc['gols_1_contra'] = wc['gols_1_contra'].astype('string')
wc['gols_2_contra'] = wc['gols_2_contra'].astype('string')
wc['gols_1_penalti'] = wc['gols_1_penalti'].astype('string')
wc['gols_2_penalti'] = wc['gols_2_penalti'].astype('string')
wc['cartao_vermelho_1'] = wc['cartao_vermelho_1'].astype('string')
wc['cartao_vermelho_2'] = wc['cartao_vermelho_2'].astype('string')
wc['cartao_amarelo_1'] = wc['cartao_amarelo_1'].astype('string')
wc['cartao_amarelo_2'] = wc['cartao_amarelo_2'].astype('string')
wc['copa'] = wc['copa'].astype('string')
wc.info()

wc.to_csv('wc_formatado.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312 entries, 0 to 1311
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   time_1             1312 non-null   string
#  1   time_2             1312 non-null   string
#  2   gols_1             1312 non-null   int64
#  3   gols_2             1312 non-null   int64
#  4   data               1312 non-null   datetime64[ns]
#  5   ano                1312 non-null   int64
#  6   país_sede          1312 non-null   string
#  7   comparecimento     1312 non-null   int64
#  8   resultado          1312 non-null   string
#  9   rodada             1312 non-null   category
#  10  gols_1_detalhes    970 non-null    string
#  11  gols_2_detalhes    771 non-null    string
#  12  gols_1_contra      57 non-null     string
#  13  gols_2_contra      30 non-null     string
#  14  gols_1_penalti     170 non-null    string
#  15  gols_2_penalti     119 non-null    string
#  16  cartao_vermelho_1  59 non-null     string
#  17  cartao_vermelho_2  65 non-null     string
#  18  cartao_amarelo_1   834 non-null    string
#  19  cartao_amarelo_2   857 non-null    string
#  20  copa               1312 non-null   string
# dtypes: category(1), datetime64[ns](1), int64(4), string(15)
# memory usage: 206.8 KB

# %% [markdown]
# #### Q2.
# Apresente a linha do dataframe `wc` que corresponde ao jogo com maior audiência da história.

# %%
max_comparecimento = wc['comparecimento'].idxmax()
print(wc.loc[max_comparecimento])
# Out:
# time_1                           Uruguay
# time_2                            Brazil
# gols_1                                 2
# gols_2                                 1
# data                 1950-07-16 00:00:00
#                             ...
# cartao_vermelho_1                   <NA>
# cartao_vermelho_2                   <NA>
# cartao_amarelo_1                    <NA>
# cartao_amarelo_2                    <NA>
# copa                           Masculina
# Name: 1238, Length: 21, dtype: object

# %% [markdown]
# #### Q3.
# Aplicando operações sobre as colunas `ano` e `copa` do dataframe `wc`, apresente quantas copas femininas e quantas copas masculinas já aconteceram na história.
#
# Exemplo de saída (valores inventados):
# ```
# Masculina: 22
# Feminina: 9
# ```

# %%
copas = wc[['ano', 'copa']].drop_duplicates().groupby('copa').count()
copas_masc=copas.loc["Masculina","ano"]
copas_fem=copas.loc["Feminina",'ano']
print(f"Masculina: {copas_masc}")
print(f"Feminina: {copas_fem}")
# Out:
# Masculina: 22
# Feminina: 9

# %% [markdown]
# #### Q3.
# Crie um dataframe `participacao` com as colunas `país`, `copa`, e `num_copas` que armazena a quantidade de copas do mundo que cada país participou, informando se é da copa masculina ou feminina. Ao final imprima, como apresentado a seguir, o top 5 países de cada competição que mais participou de copas do mundo.
#
# Exemplo de saída (valores inventados):
# ```
# país            copa        num_copas
# Brazil          Feminina    8
# Unites States   Feminina    8
# Germany         Feminina    8
# Japan           Feminina    7
# Colombia        Feminina    7
# ```
#
# ```
# país            copa        num_copas
# Brazil          Masculina   21
# Germany         Masculina   21
# Argentina       Masculina   20
# England         Masculina   20
# Mexico          Masculina   20
# ```

# %%
países = pd.concat([
    wc[['time_1', 'copa', 'ano']].rename(columns={'time_1': 'país'}),
    wc[['time_2', 'copa', 'ano']].rename(columns={'time_2': 'país'})
])
participacao = países.drop_duplicates().groupby(['país', 'copa']).size().reset_index(name='num_copas')

top5_feminina = participacao[participacao['copa'] == 'Feminina'].nlargest(5, 'num_copas')
top5_masculina = participacao[participacao['copa'] == 'Masculina'].nlargest(5, 'num_copas')

print(top5_feminina)
print(top5_masculina)
# Out:
#        país      copa  num_copas
# 10   Brazil  Feminina          9
# 45  Germany  Feminina          9
# 63    Japan  Feminina          9
# 78  Nigeria  Feminina          9
# 81   Norway  Feminina          9
#          país       copa  num_copas
# 11     Brazil  Masculina         22
# 3   Argentina  Masculina         18
# 60      Italy  Masculina         18
# 71     Mexico  Masculina         17
# 40    England  Masculina         16

# %% [markdown]
# #### Q4.
# * Crie um dataframe `gols` com duas colunas `país` e `total_gols` com o total de gols marcados por cada país durante todas as copas do mundo, juntando gols em casa (`gols_1`) e gols como time visitante (`gols_2`).
# * Imprima o dataframe `gols` ordenado de forma decrescente, para que os times com mais gols fiquem no topo.
#
# Segue um exemplo ilustrativo com o formato do dataframe resultado:
#
# ```
# país        total_gols
# Brazil      120
# Argentina   112
# Germany     107
# ...
# ```

# %%
gols = pd.concat([
    wc[['time_1', 'gols_1']].rename(columns={'time_1': 'país', 'gols_1': 'gols'}),
    wc[['time_2', 'gols_2']].rename(columns={'time_2': 'país', 'gols_2': 'gols'})
])

gols = gols.groupby('país')['gols'].sum().reset_index(name='total_gols')
gols = gols.sort_values(by='total_gols', ascending=False).reset_index(drop=True)

print(gols)
# Out:
#                    país  total_gols
# 0                Brazil         308
# 1               Germany         254
# 2         United States         182
# 3                France         180
# 4                Sweden         165
# ..                  ...         ...
# 87                Qatar           1
# 88    Dutch East Indies           0
# 89  Trinidad and Tobago           0
# 90              Vietnam           0
# 91                Zaire           0
#
# [92 rows x 2 columns]

# %% [markdown]
# #### Q5.
# Qual país tomou mais cartões amarelos somando todas as copas?
#
# Neste exercício você vai trabalhar com as colunas `cartao_amarelo_1` e `cartao_amarelo_2` onde cada observação é uma string represetando uma lista dos cartões amarelos de um único jogo na forma `minuto|placar|jogador(a)`. Por exemplo:
# ```
# ['16’|1:0|Rosana Gómez', '20’|2:0|Gabriela Chávez]
# ```
#
# Recomendo criar colunas `num_cartoes_1` e `num_cartoes_2` a partir de cada coluna `cartao_amarelo_X` usando o método genérico `apply` para chamar uma função que você vai criar para transformar uma observação de cartão amarelo em uma contagem de elementos da lista.
#
# Lembre de levar em consideração que muitas observações são `NaN`.
#
# Em seguida faça sua mágica para agrupar as informações por país, acumular os cartões de jogos em casa e jogos visitante, e produzir o resultado final como apresentado a seguir (valores inventados):
#
# ```
# país        cartões amarelos
# Argentina   97
# England     93
# Australia   93
# ...
# ```

# %%
def contar_cartoes(cartoes):
    lista_cartoes=[]
    if pd.isna(cartoes):
        return 0
    lista_cartoes = cartoes.split(',')
    return len(lista_cartoes)

wc['num_cartoes_1'] = wc['cartao_amarelo_1'].apply(contar_cartoes)
wc['num_cartoes_2'] = wc['cartao_amarelo_2'].apply(contar_cartoes)


cartoes = pd.concat([
    wc[['time_1', 'num_cartoes_1']].rename(columns={'time_1': 'país', 'num_cartoes_1': 'cartoes'}),
    wc[['time_2', 'num_cartoes_2']].rename(columns={'time_2': 'país', 'num_cartoes_2': 'cartoes'})
])

cartoes_total = cartoes.groupby('país')['cartoes'].sum().reset_index(name='cartões_amarelos')

cartoes_total = cartoes_total.sort_values(by='cartões_amarelos', ascending=False).reset_index(drop=True)

print(cartoes_total)
# Out:
#                  país  cartões_amarelos
# 0              Brazil               168
# 1           Argentina               162
# 2             Germany               124
# 3         Netherlands               117
# 4               Italy               108
# ..                ...               ...
# 87            Vietnam                 2
# 88              Zaire                 2
# 89     Chinese Taipei                 1
# 90  Dutch East Indies                 0
# 91               Cuba                 0
#
# [92 rows x 2 columns]

# %% [markdown]
# #### Q6.
# Qual o top10 jogadores com mais gols em copa? Considere gols em jogo e gols de pênalti.
#
# Para conseguir essa informação, você precisará trabalhar com as colunas:
# ```
# 10  gols_1_detalhes
# 11  gols_2_detalhes
# 14  gols_1_penalti
# 15  gols_2_penalti
# ```
#
# Essas também são colunas textuais, onde cada observações apresenta todos os gols de uma partida separados pelo caracter `|`. Cada gol está na forma `'Jogador(a) · minuto’'`. Por exemplo:
# ```
# 'Alex Morgan · 12’|Rose Lavelle · 20’'
# ```
#
# Lembre de levar em consideração que muitas observações são `NaN`.
#
# Recomendo criar um dicionário à parte, onde cada chave será um jogador encontrado nessas colunas do dataframe `wc` e o valor correspondente será a contagem de ocorrências desses nomes.
#
# Em seguida basta converter o seu dicionário em um dataframe e imprimí-lo na forma (valores não são inventados 😁):
# ```
# jogador(a)      num_gols
# Marta           17
# Miroslav Klose  16
# ...
# ```

# %%
def add_gols(texto, dicionario):
    if pd.isna(texto):
        return
    gols = texto.split('|')
    for gol in gols:
        jogador = gol.split('·')[0]
        jogador = jogador.replace(" (P)","")
        if jogador in dicionario:
            dicionario[jogador] += 1
        else:
            dicionario[jogador] = 1


dicionario_gols = {}

wc['gols_1_detalhes'].apply(add_gols, dicionario=dicionario_gols)
wc['gols_2_detalhes'].apply(add_gols, dicionario=dicionario_gols)
wc['gols_1_penalti'].apply(add_gols, dicionario=dicionario_gols)
wc['gols_2_penalti'].apply(add_gols, dicionario=dicionario_gols)
print(dicionario_gols)

gols_df = pd.DataFrame(dicionario_gols.items(), columns=['jogador','num_gols'])
gols_df = gols_df.sort_values(by='num_gols', ascending=False).reset_index(drop=True)

print(gols_df)
# Out:
# {'Olga Carmona ': 2, 'Kosovare Asllani ': 4, 'Sam Kerr ': 6, 'Salma Paralluelo ': 2, 'Lauren Hemp ': 3, 'Alessia Russo ': 3, 'Honoka Hayashi ': 1, 'Catalina Usme ': 3, 'Kadidiatou Diani ': 4, 'Kenza Dali ': 1, 'Eugénie Le Sommer ': 8, 'Caitlin Foord ': 2, 'Hayley Raso ': 3, 'Jill Roord ': 5, 'Lineth Beerensteyn ': 2, 'Risa Shimizu ': 1, 'Hinata Miyazawa ': 5, 'Anissa Lahmari ': 1, 'Cho So-hyun ': 2, 'Hildah Magaia ': 2, 'Thembi Kgatlana ': 3, 'Marta Cox ': 1, 'Lineth Cedeño ': 1, 'Riko Ueki ': 2, 'Mina Tanaka ': 2, 'Melissa Herrera ': 2, 'Sophie Román Haug ': 3, 'Caroline Graham Hansen ': 2, 'Amanda Ilestedt ': 4, 'Fridolina Rolfö ': 4, 'Stina Blackstenius ': 3, 'Rebecka Blomqvist ': 3, 'Wendie Renard ': 5, 'Sophia Braun ': 1, 'Romina Núñez ': 1, 'Lauren James ': 3, 'Lindsey Horan ': 4, 'Telma Encarnação ': 1, 'Kika Nazareth ': 1, 'Emily van Egmond ': 2, 'Alanna Kennedy ': 1, 'Hikaru Naomoto ': 1, 'Aoba Fujino ': 1, 'Teresa Abelleira ': 1, 'Jennifer Hermoso ': 6, 'Alba Redondo ': 3, 'Adriana Leon ': 1, 'Linda Caicedo ': 2, 'Cristiana Girelli ': 4, 'Alexandra Popp ': 7, 'Klara Bühl ': 1, 'Lea Schüller ': 2, 'Ary Borges ': 3, 'Beatriz ': 1, 'Stefanie van der Gragt ': 3, 'Sophia Smith ': 2, 'Amalie Vangsgaard ': 1, 'Aitana Bonmatí ': 3, 'Esther González ': 1, 'Hannah Wilkinson ': 3, 'Rose Lavelle ': 3, 'Fran Kirby ': 2, 'Jackie Groenen ': 1, 'Ellen White ': 7, 'Lina Magull ': 2, 'Valentina Giacinti ': 1, 'Aurora Galli ': 3, 'Lieke Martens ': 4, 'Steph Houghton ': 2, 'Alex Greenwood ': 1, 'Valérie Gauvin ': 2, 'Amandine Henry ': 3, 'Isabell Herlovsen ': 6, 'Anouk Dekker ': 1, 'Ajara Nchout ': 3, 'Kim Little ': 1, 'Jennifer Beattie ': 1, 'Erin Cuthbert ': 1, 'Havana Solaun ': 1, 'Yeo Min-ji ': 1, 'Linda Sembrant ': 3, 'Lina Hurtig ': 1, 'Carli Lloyd ': 10, 'Julie Ertz ': 1, 'Vivianne Miedema ': 3, 'Dominique Janssen ': 1, 'Jessie Fleming ': 1, 'Nichelle Prince ': 1, 'Mana Iwabuchi ': 2, 'Jodie Taylor ': 2, 'Chloe Logarzo ': 1, 'Asisat Oshoala ': 3, 'Sara Däbritz ': 5, 'Alex Morgan ': 9, 'Sam Mewis ': 2, 'Megan Rapinoe ': 9, 'Mallory Swanson ': 1, 'Kadeisha Buchanan ': 1, 'Cristiane ': 11, 'Giulia Gwinn ': 1, 'Lucía García ': 1, 'Guro Reiten ': 3, 'Lisa-Marie Karlseng Utland ': 1, 'Lauren Holiday ': 3, 'Tobin Heath ': 1, "Kelley O'Hara ": 1, 'Lucy Bronze ': 3, 'Saori Ariyoshi ': 1, 'Mizuho Sakaguchi ': 1, 'Solveig Gulbrandsen ': 4, 'Josée Bélanger ': 1, 'Marie-Laure Delie ': 5, 'Élodie Thomis ': 3, 'Anja Mittag ': 5, 'Célia Šašić ': 8, 'Dzsenifer Marozsán ': 1, 'Wang Shanshan ': 2, 'Karen Carney ': 2, 'Kim Soo-yun ': 1, 'Ana-Maria Crnogorčević ': 1, 'Lisa De Vanna ': 7, "Ange N'Guessan ": 2, 'Kirsten van de Ven ': 2, 'Andressa ': 1, 'Jeon Ga-eul ': 1, 'Kyah Simon ': 5, 'Eseosa Aigbogun ': 1, 'Fabienne Humm ': 3, 'Ramona Bachmann ': 4, 'Martina Moser ': 1, 'Aya Sameshima ': 1, 'Yuika Sugasawa ': 2, 'Wang Lisi ': 2, 'Josée Nahi ': 1, 'Vicky Losada ': 1, 'Daniela Montoya ': 1, 'Formiga ': 2, 'Nilla Fischer ': 1, 'Madeleine Ngono Mani ': 2, 'Gaëlle Enganamouit ': 3, 'Christen Press ': 2, 'Trine Rønning ': 1, 'Ada Hegerberg ': 3, 'Simone Laudehr ': 3, 'Melanie Behringer ': 3, 'Aya Miyama ': 6, 'Homare Sawa ': 8, 'Lotta Schelin ': 4, 'Marie Hammarström ': 1, 'Sonia Bompastor ': 1, 'Nahomi Kawasumi ': 2, 'Therese Sjögran ': 1, 'Lisa Dahlkvist ': 3, 'Marta ': 17, 'Jill Scott ': 4, 'Rachel Yankey ': 1, 'Rebecca Smith ': 1, 'Laura Georges ': 1, 'Leena Khamis ': 1, 'Rosana ': 3, "Heather O'Reilly ": 3, 'Shinobu Ohno ': 1, 'Sarah Gregorius ': 1, 'Emilie Haavi ': 1, 'Rachel Van Hollebeke ': 1, 'Yūki Nagasato ': 4, 'Mónica Ocampo ': 1, 'Kerstin Garefrekes ': 8, 'Ragnhild Gulbrandsen ': 6, 'Birgit Prinz ': 14, 'Kerstin Stegemann ': 1, 'Martina Müller ': 3, 'Renate Lingor ': 5, 'Annike Krahn ': 1, 'Abby Wambach ': 14, 'Shannon Boxx ': 3, 'Kristine Lilly ': 8, 'Lene Storløkken ': 1, 'Lise Klaveness ': 1, 'Collette McCallum ': 1, 'Cheryl Salisbury ': 2, 'Pretinha ': 5, 'Li Jie ': 2, 'Xie Caixia ': 1, 'Ri Un-suk ': 1, 'Eva Nadia González ': 1, 'Christ ...
#                  jogador  num_gols
# 0                 Marta         17
# 1        Miroslav Klose         16
# 2               Ronaldo         15
# 3          Birgit Prinz         14
# 4           Gerd Müller         14
# ...                  ...       ...
# 1836        Angie Ponce          1
# 1837      Florence Okoe          1
# 1838        Vicky Exley          1
# 1839  Annette Thychosen          1
# 1840       Ismaila Sarr          1
#
# [1841 rows x 2 columns]
